# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
r.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 100,\n"value": [{"StationIdentifier": "1730H066","RecordTime": "Nov 29, 2019 11:50:00 PM","WaterLevel": 138.52},{"StationIdentifier": "1730H061","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 266.24},{"StationIdentifier": "1730H043","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 23.06},{"StationIdentifier": "1740H002","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 4.42},{"StationIdentifier": "1540H032","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 20.21},{"StationIdentifier": "2420H019","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 109.98},{"StationIdentifier": "1670H004","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 2.99},{"StationIdentifier": "1730H074","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 245.48},{"StationIdentifier": "1730H070","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 226.21},{"StationIdentifier": "1540H029","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 12.78},{"StationIdentifier": "2370H025","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 261.61},{"StationIdentifier": "1730H079","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 548.82},{"StationIdentifier": "1430H056","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 79.82},{"StationIdentifier": "1730H072","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 248.85},{"StationIdentifier": "2560H019","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 4.43},{"StationIdentifier": "2370H017","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 58.49},{"StationIdentifier": "1510H084","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 145.01},{"StationIdentifier": "1550H014","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 26.76},{"StationIdentifier": "1730H069","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 141.1},{"StationIdentifier": "2370H019","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 156.02},{"StationIdentifier": "1430H045","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 91.65},{"StationIdentifier": "2560H025","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 3.16},{"StationIdentifier": "1660H011","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 1.47},{"StationIdentifier": "1680H005","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 0.4},{"StationIdentifier": "1630H032","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 1},{"StationIdentifier": "1630H030","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 1.54},{"StationIdentifier": "1340H011","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 7.35},{"StationIdentifier": "1540H033","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 23.3},{"StationIdentifier": "1630H018","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 10.03},{"StationIdentifier": "2420H046","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 35.95},{"StationIdentifier": "2370H004","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 192.58},{"StationIdentifier": "1430H040","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 19.42},{"StationIdentifier": "2560H022","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 194.53},{"StationIdentifier": "1660H010","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 7.45},{"StationIdentifier": "2420H037","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 133.41},{"StationIdentifier": "1730H057","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 43.45},{"StationIdentifier": "1630H027","RecordTime": "Nov 29, 2019 11:20:00 PM","WaterLevel": 26.21},{"StationIdentifier": "1540H030","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 27.19},{"StationIdentifier": "1300H023","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 52.22},{"StationIdentifier": "1350H027","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 145.84},{"StationIdentifier": "1580H022","RecordTime": "Nov 29, 2019 11:40:00 PM","WaterLevel": 1 ...

# %%
import json

json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'StationIdentifier': '1730H066',
#    'RecordTime': 'Nov 29, 2019 11:50:00 PM',
#    'WaterLevel': 138.52},
#   {'StationIdentifier': '1730H061',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 266.24},
#   {'StationIdentifier': '1730H043',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 23.06},
#   {'StationIdentifier': '1740H002',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 4.42},
#   {'StationIdentifier': '1540H032',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 20.21},
#   {'StationIdentifier': '2420H019',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 109.98},
#   {'StationIdentifier': '1670H004',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 2.99},
#   {'StationIdentifier': '1730H074',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 245.48},
#   {'StationIdentifier': '1730H070',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 226.21},
#   {'StationIdentifier': '1540H029',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 12.78},
#   {'StationIdentifier': '2370H025',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 261.61},
#   {'StationIdentifier': '1730H079',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 548.82},
#   {'StationIdentifier': '1430H056',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 79.82},
#   {'StationIdentifier': '1730H072',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 248.85},
#   {'StationIdentifier': '2560H019',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 4.43},
#   {'StationIdentifier': '2370H017',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 58.49},
#   {'StationIdentifier': '1510H084',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 145.01},
#   {'StationIdentifier': '1550H014',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 26.76},
#   {'StationIdentifier': '1730H069',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 141.1},
#   {'StationIdentifier': '2370H019',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 156.02},
#   {'StationIdentifier': '1430H045',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 91.65},
#   {'StationIdentifier': '2560H025',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 3.16},
#   {'StationIdentifier': '1660H011',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 1.47},
#   {'StationIdentifier': '1680H005',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 0.4},
#   {'StationIdentifier': '1630H032',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 1},
#   {'StationIdentifier': '1630H030',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 1.54},
#   {'StationIdentifier': '1340H011',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 7.35},
#   {'StationIdentifier': '1540H033',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 23.3},
#   {'StationIdentifier': '1630H018',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 10.03},
#   {'StationIdentifier': '2420H046',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 35.95},
#   {'StationIdentifier': '2370H004',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 192.58},
#   {'StationIdentifier': '1430H040',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 19.42},
#   {'StationIdentifier': '2560H022',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 194.53},
#   {'StationIdentifier': '1660H010',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 7.45},
#   {'StationIdentifier': '2420H037',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 133.41},
#   {'StationIdentifier': '1730H057',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 43.45},
#   {'StationIdentifier': '1630H027',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 26.21},
#   {'StationIdentifier': '1540H030',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 27.19},
#   {'StationIdentifier': '1300H023',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 52.22},
#   {'StationIdentifier': '1350H027',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 145.84},
#   {'StationIdentifier': '1580H022',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 1.33},
#   {'StationIdentifier': '1660H013',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 0.9},
#   {'StationIdentifier': '2200H025',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 207.16},
#   {'StationIdentifier': '1310H001',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 13.65},
#   {'StationIdentifier': '2560H006',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 3.17},
#   {'StationIdentifier': '1650H014',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 0.96},
#   {'StationIdentifier': '2200H011',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 25.62},
#   {'StationIdentifier': '1510H076',
#    'RecordTime': 'Nov 29, 2019 11:30:00 PM',
#    'WaterLevel': 4.87},
#   {'StationIdentifier': '1630H024',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 69.12},
#   {'StationIdentifier': '1540H009',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 1.15},
#   {'StationIdentifier': '1510H064',
#    'RecordTime': 'Nov 29, 2019 11:30:00 PM',
#    'WaterLevel': 265.07},
#   {'StationIdentifier': '1350H020',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 220.79},
#   {'StationIdentifier': '1430H037',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 380.47},
#   {'StationIdentifier': '1650H011',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 0.81},
#   {'StationIdentifier': '1630H023',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 0.92},
#   {'StationIdentifier': '2200H007',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 155.92},
#   {'StationIdentifier': '1300H022',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 1.47},
#   {'StationIdentifier': '1300H020',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 251.44},
#   {'StationIdentifier': '1630H037',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 9.33},
#   {'StationIdentifier': '1430H054',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 48.25},
#   {'StationIdentifier': '1580H007',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 23.66},
#   {'StationIdentifier': '1520H008',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 78.22},
#   {'StationIdentifier': '1300H014',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 208.95},
#   {'StationIdentifier': '1590H015',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 9.3},
#   {'StationIdentifier': '1350H016',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 98.26},
#   {'StationIdentifier': '1730H075',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': -999998},
#   {'StationIdentifier': '1650H008',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 0.89},
#   {'StationIdentifier': '1630H005',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 39.78},
#   {'StationIdentifier': '1740H011',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 6.62},
#   {'StationIdentifier': '1290H007',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 12.56},
#   {'StationIdentifier': '1300H019',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': -999998},
#   {'StationIdentifier': '1510H081',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 229.09},
#   {'StationIdentifier': '1430H047',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 72.38},
#   {'StationIdentifier': '1420H053',
#    'RecordTime': 'Nov 29, 2019 11:30:00 PM',
#    'WaterLevel': 471.65},
#   {'StationIdentifier': '1510H086',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 317.98},
#   {'StationIdentifier': '1430H030',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 87.54},
#   {'StationIdentifier': '1430H052',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 173.07},
#   {'StationIdentifier': '1340H015',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 50.05},
#   {'StationIdentifier': '1730H065',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 90.7},
#   {'StationIdentifier': '1650H006',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 1.19},
#   {'StationIdentifier': '1590H013',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 20.74},
#   {'StationIdentifier': '1740H009',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 32.38},
#   {'StationIdentifier': '1280H001',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 71.47},
#   {'StationIdentifier': '1350H025',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 1.97},
#   {'StationIdentifier': '1510H057',
#    'RecordTime': 'Nov 29, 2019 11:30:00 PM',
#    'WaterLevel': 88.47},
#   {'StationIdentifier': '1420H058',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 440.48},
#   {'StationIdentifier': '1400H020',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 318.71},
#   {'StationIdentifier': '1350H022',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 253.93},
#   {'StationIdentifier': '1430H028',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 23.58},
#   {'StationIdentifier': '1420H056',
#    'RecordTime': 'Nov 29, 2019 11:30:00 PM',
#    'WaterLevel': 196.5},
#   {'StationIdentifier': '2200H029',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 145.16},
#   {'StationIdentifier': '1730H058',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 113.9},
#   {'StationIdentifier': '1630H035',
#    'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'WaterLevel': 402.47},
#   {'StationIdentifier': '1140H129',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 27.13},
#   {'StationIdentifier': '1730H076',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 58.07},
#   {'StationIdentifier': '1140H102',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 209.27},
#   {'StationIdentifier': '1510H049',
#    'RecordTime': 'Nov 29, 2019 11:30:00 PM',
#    'WaterLevel': 470.83},
#   {'StationIdentifier': '1350H023',
#    'RecordTime': 'Nov 29, 2019 11:40:00 PM',
#    'WaterLevel': 256.29},
#   {'StationIdentifier': '1140H110',
#    'RecordTime': 'Nov 29, 2019 11:30:00 PM',
#    'WaterLevel': 42.65},
#   {'StationIdentifier': '1400H019',
#    'RecordTime': 'Nov 29, 2019 11:30:00 PM',
#    'WaterLevel': 310.14}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
payload = {'value':'StationIdentifier', 'value':'RecordTime'}
r = requests.get("http://odata.wra.gov.tw/v4/RealtimeWaterLevel", params=payload)
json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1670H004',
#    'WaterLevel': 2.99},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '2560H023',
#    'WaterLevel': 13.05},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1660H012',
#    'WaterLevel': 0.55},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '2560H024',
#    'WaterLevel': 202.64},
#   {'RecordTime': 'Nov 30, 2019 12:00:00 AM',
#    'StationIdentifier': '2420H036',
#    'WaterLevel': 164.36},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1650H015',
#    'WaterLevel': 0.65},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '2560H020',
#    'WaterLevel': -0.06},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '2420H019',
#    'WaterLevel': 109.97},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1650H010',
#    'WaterLevel': 0.8},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '2370H025',
#    'WaterLevel': 261.62},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '2560H019',
#    'WaterLevel': 4.44},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1850H004',
#    'WaterLevel': 72.04},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1630H040',
#    'WaterLevel': 1.75},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1730H066',
#    'WaterLevel': 138.52},
#   {'RecordTime': 'Nov 29, 2019 11:50:00 PM',
#    'StationIdentifier': '1630H030',
#    'WaterLevel': 1.55},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '2420H043',
#    'WaterLevel': 79.4},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '2500H003',
#    'WaterLevel': 32.07},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1850H005',
#    'WaterLevel': 22.1},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1730H072',
#    'WaterLevel': 248.85},
#   {'RecordTime': 'Nov 29, 2019 11:20:00 PM',
#    'StationIdentifier': '1630H034',
#    'WaterLevel': 278.35},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1730H061',
#    'WaterLevel': 266.24},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1630H018',
#    'WaterLevel': 10.03},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1630H023',
#    'WaterLevel': 0.9},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1650H012',
#    'WaterLevel': 0.75},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1740H010',
#    'WaterLevel': 47.05},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1730H068',
#    'WaterLevel': 10.14},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1510H082',
#    'WaterLevel': 752.39},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1730H043',
#    'WaterLevel': 23.05},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1590H016',
#    'WaterLevel': 11.21},
#   {'RecordTime': 'Nov 30, 2019 12:20:00 AM',
#    'StationIdentifier': '1630H005',
#    'WaterLevel': 39.76},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1740H008',
#    'WaterLevel': 1.11},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1730H045',
#    'WaterLevel': 5.12},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1650H009',
#    'WaterLevel': 0.73},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1510H058',
#    'WaterLevel': 12.2},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1660H009',
#    'WaterLevel': 4.81},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1630H036',
#    'WaterLevel': 65.82},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1590H013',
#    'WaterLevel': 20.75},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1740H002',
#    'WaterLevel': 4.42},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1680H005',
#    'WaterLevel': 0.33},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1580H022',
#    'WaterLevel': 1.4},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1510H050',
#    'WaterLevel': 155.51},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1650H013',
#    'WaterLevel': 5.64},
#   {'RecordTime': 'Nov 29, 2019 11:50:00 PM',
#    'StationIdentifier': '1630H032',
#    'WaterLevel': 1.01},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1580H018',
#    'WaterLevel': 21.24},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1730H070',
#    'WaterLevel': 226.21},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1550H012',
#    'WaterLevel': 0.9},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1430H037',
#    'WaterLevel': 380.48},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1430H061',
#    'WaterLevel': 24.98},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1540H032',
#    'WaterLevel': 20.23},
#   {'RecordTime': 'Nov 29, 2019 11:50:00 PM',
#    'StationIdentifier': '1630H027',
#    'WaterLevel': 26.21},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1580H008',
#    'WaterLevel': 19.41},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1580H021',
#    'WaterLevel': 1.33},
#   {'RecordTime': 'Nov 30, 2019 12:00:00 AM',
#    'StationIdentifier': '1540H030',
#    'WaterLevel': 27.19},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1430H030',
#    'WaterLevel': 87.54},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1430H056',
#    'WaterLevel': 79.82},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1540H029',
#    'WaterLevel': 12.79},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': 25.74},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1630H024',
#    'WaterLevel': 69.13},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1550H017',
#    'WaterLevel': 15.72},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1540H009',
#    'WaterLevel': 1.43},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1430H028',
#    'WaterLevel': 23.58},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1430H045',
#    'WaterLevel': 91.66},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1580H001',
#    'WaterLevel': 224.2},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1520H008',
#    'WaterLevel': 78.22},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1430H054',
#    'WaterLevel': 48.25},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1420H054',
#    'WaterLevel': 704.2},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1550H014',
#    'WaterLevel': 26.76},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1510H084',
#    'WaterLevel': 145.01},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1420H057',
#    'WaterLevel': 639.37},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1510H086',
#    'WaterLevel': 317.99},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1430H051',
#    'WaterLevel': 95.66},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1430H040',
#    'WaterLevel': 19.42},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1420H049',
#    'WaterLevel': 54.11},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1540H039',
#    'WaterLevel': 39},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1510H080',
#    'WaterLevel': 1068.95},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1510H075',
#    'WaterLevel': 346.56},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1400H018',
#    'WaterLevel': 55.22},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1430H047',
#    'WaterLevel': 72.39},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1310H001',
#    'WaterLevel': 13.66},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1400H015',
#    'WaterLevel': -999998},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1540H037',
#    'WaterLevel': 32.03},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1510H079',
#    'WaterLevel': 187.72},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1350H022',
#    'WaterLevel': 253.91},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1400H009',
#    'WaterLevel': 191.55},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1420H058',
#    'WaterLevel': 440.49},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1350H025',
#    'WaterLevel': 2.18},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1540H033',
#    'WaterLevel': 23.3},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1300H022',
#    'WaterLevel': 1.64},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1510H071',
#    'WaterLevel': 20.64},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1350H018',
#    'WaterLevel': 282.04},
#   {'RecordTime': 'Nov 30, 2019 12:15:00 AM',
#    'StationIdentifier': '1140H108',
#    'WaterLevel': 12.24},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1430H058',
#    'WaterLevel': 83.03},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1350H023',
#    'WaterLevel': 256.28},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1350H031',
#    'WaterLevel': 2.12},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1340H011',
#    'WaterLevel': 7.34},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1420H055',
#    'WaterLevel': 318.54},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1350H001',
#    'WaterLevel': 169.8},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1140H082',
#    'WaterLevel': 7.03},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1290H002',
#    'WaterLevel': 40.94},
#   {'RecordTime': 'Nov 30, 2019 12:10:00 AM',
#    'StationIdentifier': '1350H029',
#    'WaterLevel': 175.93}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
